# %%
# importando as bibliotecas
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Realizar a leitura do meu arquivo csv
df = pd.read_csv('C:/Users/dsadm/Desktop/Desenvolvimento_Back-End_2_semestre_ADS/Aula 3 e 4/base_de_dados/monitoramento_tempo.csv')

# %%
# exibindo as primeiras linhas do dataframe
df.head() # exibe as 4 primeiras linhas do dataframe
# Out:
#    temperatura  pressão  humidade  direção do vento  velocidade do vento  \
# 0   282.080000   1024.0      81.0               0.0                  0.0
# 1   282.080000   1024.0      81.0               0.0                  0.0
# 2   282.083252   1024.0      80.0               4.0                  0.0
# 3   282.091866   1024.0      80.0              18.0                  0.0
# 4   282.100481   1024.0      80.0              31.0                  0.0
#
#   dia_da_semana                 data
# 0       Domingo  2012-10-01 12:00:00
# 1       Domingo  2012-10-01 13:00:00
# 2       Domingo  2012-10-01 14:00:00
# 3       Domingo  2012-10-01 15:00:00
# 4       Domingo  2012-10-01 16:00:00

# %%
# importa a biblioteca datetime
import datetime # Biblioteca que permite a transformação da data que ea um object
# em datetime
df['data'] = pd.to_datetime(df['data']) # converti a data de object para datetime
plt.figure(figsize=(15,8))
plt.plot(df['data'],df['temperatura'])
plt.xlabel('Data e hora')
plt.ylabel('Temperatura')
# Out:
# Text(0, 0.5, 'Temperatura')

# %%
fig = plt.figure(figsize=(15,8)) # crio uma variável fig para armazenar o tamanho da figura
eixo = fig.add_axes([0,0,1,1]) # define o tamanho dos eixos do gráfico
eixo.plot(df['data'],df['temperatura']/10,color='red',lw=0.7,linestyle='--')
eixo.set_title('Temperatura no momento',fontsize=25) # título do gráfico
eixo.legend(['temperatura'],loc='lower right',fontsize = 15)
eixo.set_xlabel('Ano',fontsize=20)
eixo.set_ylabel('Temperatura',fontsize=20)
# Out:
# Text(0, 0.5, 'Temperatura')

# %%
# Selecionando o período da base de dados
fig = plt.figure(figsize=(15,8))
plt.rcParams['font.size']='20'
eixo=fig.add_axes([0,0,1,1])
eixo.plot(df['data'],df['temperatura'],color='b',lw=0.5,linestyle='--')
eixo.set_xlim(datetime.datetime(2015,1,1), datetime.datetime(2015,12,31)) # xlim define o valor inicial e o valor final
eixo.set_title('Temperatura = Ano 2015',fontsize=25)
eixo.legend(['temperatura'],fontsize=20)
eixo.set_xlabel('Ano',fontsize=20)
plt.xticks(rotation=45,fontsize=15,ha='right') # ajusta o espaçamento
plt.show()
